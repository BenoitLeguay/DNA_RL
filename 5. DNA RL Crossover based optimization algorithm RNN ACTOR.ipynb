# %% [markdown]
# # DNA RL: Crossover based optimization algorithm

# %% [markdown]
# Importing Libraries

# %%
import dna_env
import a2c
import torch
import variable as v
from tqdm import tqdm
from train_session import TrainSession
import matplotlib.pyplot as plt
from copy import deepcopy
import numpy as np

# %% [markdown]
# Initializing Environment

# %%
sequence_length = 36
render = True
state_representation = 'latent'
use_test_set = True
action_constraints = {'co_length': (-1, 12), 
                      'opt_start_point': (12, 24),
                      'co_start_point': (24, 36)}
early_stop_reward = {'reward_low_threshold': -1,
                     'reward_high_threshold': .9, 
                     'patience': 200}
env = dna_env.DnaRLEnv(action_constraints=action_constraints, 
                       early_stop_reward=early_stop_reward, 
                       use_test_set=use_test_set,
                       sequence_length=sequence_length, 
                       state_representation=state_representation)
env.reset()
train_session = None

# %%
seed = 30
state_dim = env.get_state_dim()
action_dim = env.get_action_dim()
print(f"state dim: {state_dim}")
print(f"action dim: {action_dim}")
# Out:
# state dim: (400,)
# action dim: (3, 36)

# %% [markdown]
# Creating our agent

# %%
critic_init = {
    'seed': seed,
    'action_dim': action_dim[0],
    'state_representation': state_representation,
    'network': {
        'i_size': state_dim[0],
        'l1_size': 200,
        'l2_size': 50,
               },
    'optimizer': {
        'lr': 1e-3
    }
}
actor_init = {
    'entropy_learning_rate': .2,
    'seed': seed,
    'action_dim': action_dim[0],
    'state_representation': state_representation,
    'network': {
        'i_size': state_dim[0], 
        'l1_size': 200,
        'hidden_size': 75,
        'o_size': sequence_length
               },
    'optimizer': {
        'lr': 1e-3
    }
}
a2c_init = {
    'actor_type': 'actor_rnn',
    'seed': seed,
    'discount_factor': 1.0, 
    'state_dim': state_dim, 
    'action_space': 3, 
    'actor': actor_init, 
    'critic': critic_init
}

# %%
if not train_session:
    print('Train Session reset')
    train_session = TrainSession({}, env, seed)
# Out:
# Train Session reset

# %%
agents_created = {
    'a2c_agent': a2c.A2C(a2c_init)
}
manual_agent_names = train_session.append_agents(agents_created)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-ae86f76c4425> in <module>
#       1 agents_created = {
# ----> 2     'a2c_agent': a2c.A2C(a2c_init)
#       3 }
#       4 manual_agent_names = train_session.append_agents(agents_created)
#
# ~/Documents/work/RL_DNA/a2c.py in __init__(self, init_a2c)
#      13         self.action_dim = init_a2c["action_space"]
#      14         self.critic = Critic(init_a2c['critic']).cuda()
# ---> 15         self.actor = var.actor_types[init_a2c['actor_type']](init_a2c['actor']).cuda()
#      16         self.optim_actor = None
#      17         self.random_generator = np.random.RandomState(seed=init_a2c['seed'])
#
# ~/Documents/work/RL_DNA/a2c.py in __init__(self, actor_vanilla_init)
#     213         self.action_names = ['co_length', 'opt_start_point', 'co_start_point']
#     214         self.actors = {action_name: OneActionActor(actor_vanilla_init[action_name])
# --> 215                        for action_name in self.action_names}
#     216         self.loss_history = list()
#     217
#
# ~/Documents/work/RL_DNA/a2c.py in <dictcomp>(.0)
#     213         self.action_names = ['co_length', 'opt_start_point', 'co_start_point']
#     214         self.actors = {action_name: OneActionActor(actor_vanilla_init[action_name])
# --> 215                        for action_name in self.action_names}
#     216         self.loss_history = list()
#     217
#
# KeyError: 'co_length'

# %%
all_agent_names = train_session.agents.keys()
s = '\n- '.join(all_agent_names)
print(f"All Agents: \n- {s}")

# %%
# train_session.load_model('a2c_agent', suffix='0710-raw')

# %%
n_episode = 500
t_max_per_episode = 100
graphical = False

# %%
train_session.train(n_episode=n_episode, t_max_per_episode=t_max_per_episode,
                    graphical=graphical, agent_subset=manual_agent_names)
# Out:
# 100%|██████████| 500/500 [25:41<00:00,  3.08s/it]

# %%
train_session.plot_results(window=1, agent_subset=manual_agent_names)

# %%
train_session.env.actions_analysis()

# %%
env.step(np.array([3, 11, 11]))
# Out:
# (array([ 6.12855434e-01,  6.65016770e-01,  6.90089643e-01,  3.28149766e-01,
#          9.09646273e-01,  8.14451337e-01,  6.17662311e-01,  5.29077590e-01,
#          5.24491668e-01,  1.11022815e-01,  3.45989585e-01,  7.28929758e-01,
#          7.27378130e-01,  4.48629528e-01,  2.78487265e-01,  5.77987194e-01,
#          4.59322840e-01,  4.01569188e-01,  5.28502584e-01,  3.13728034e-01,
#          6.77334785e-01,  8.34909618e-01,  1.12881467e-01,  4.99065638e-01,
#          6.20005310e-01,  5.91773570e-01,  5.44201314e-01,  1.46471515e-01,
#          3.46612543e-01,  5.90626061e-01,  4.84171569e-01,  3.18058997e-01,
#          5.97658008e-02,  2.66679406e-01,  5.30624688e-01,  3.80432278e-01,
#          5.57236791e-01,  8.60495985e-01,  2.65050560e-01,  3.32910895e-01,
#          1.28077686e-01,  9.26032960e-02,  4.28029656e-01,  4.03561085e-01,
#          5.08883238e-01,  9.52994823e-02,  3.63049239e-01,  5.73641121e-01,
#          4.67521548e-01,  6.10570431e-01,  2.64065832e-01,  7.12804794e-01,
#         -3.00446097e-02,  3.75346750e-01,  5.54562211e-01,  5.82646608e-01,
#          7.22389698e-01,  2.82637775e-01,  4.29860622e-01,  4.89918709e-01,
#          7.87744880e-01,  4.39267486e-01,  6.98574662e-01,  4.21206892e-01,
#          4.47400272e-01,  4.91557449e-01,  3.70594680e-01,  2.60559201e-01,
#          6.61523759e-01,  9.36889291e-01,  6.04673982e-01,  5.70419788e-01,
#          1.93686441e-01,  1.38566673e-01,  6.12021387e-01,  1.77584738e-01,
#          7.20077977e-02,  6.86835110e-01,  1.47209659e-01,  3.24870706e-01,
#          4.91840988e-01,  4.22493875e-01,  7.02509701e-01,  2.90143520e-01,
#          4.42921638e-01,  3.98762286e-01,  7.10789621e-01,  8.06726336e-01,
#          7.87405550e-01,  7.53400385e-01,  5.88423789e-01,  7.39274144e-01,
#          3.15168440e-01,  3.75494242e-01,  1.99440494e-01,  3.00754458e-01,
#          9.11995411e-01,  5.40751457e-01,  5.84052682e-01,  5.28783798e-01,
#          7.02053010e-02,  9.12340879e-02,  9.25233141e-02,  5.65498136e-02,
#          1.32187277e-01,  2.59017706e-01,  1.52446911e-01,  1.14142038e-01,
#          1.63124114e-01, -4.18811664e-02,  4.05587070e-02,  1.92233622e-01,
#          1.48478240e-01,  6.76401705e-02, -1.20330751e-02,  7.86798149e-02,
#          9.19844061e-02,  3.71191166e-02,  1.59127161e-01,  3.41799445e-02,
#          1.73707291e-01,  2.34805688e-01, -2.45368015e-02,  5.25857620e-02,
#          2.26718500e-01,  1.72588140e-01,  1.41657129e-01, -3.38140614e-02,
#          1.55985458e-02,  1.38776124e-01, -4.12860699e-03,  9.09643341e-03,
#         -3.17985602e-02,  9.60623752e-03,  2.37738818e-01, -6.45990437e-03,
#          6.63697198e-02,  3.32843632e-01, -2.33622510e-02,  2.91411541e-02,
#         -7.43603036e-02, -6.09738044e-02,  1.56066447e-01,  1.55633222e-02,
#          1.35448173e-01, -2.69438066e-02,  2.45550741e-02,  5.86092398e-02,
#          2.40341555e-02,  1.83574140e-01, -5.99631155e-03,  1.50303483e-01,
#         -8.58802646e-02,  4.71096784e-02, -2.66350135e-02,  9.25495625e-02,
#          1.66136950e-01,  2.64016166e-02,  3.37927826e-02,  9.62279886e-02,
#          1.18560895e-01,  3.45600545e-02,  1.73115283e-01,  6.38125986e-02,
#          7.64488662e-03,  8.46165270e-02,  1.39840739e-02,  7.61465961e-03,
#          1.82902172e-01,  1.66731834e-01,  8.62409398e-02,  8.97538662e-02,
#         -1.64871663e-02, -8.18597991e-03,  3.05905759e-01,  2.33806390e-02,
#         -4.39553596e-02,  7.42032379e-02, -1.65029671e-02,  2.83488669e-02,
#          1.26604140e-01,  2.91016772e-02,  1.13422766e-01,  3.11158190e-04,
#          5.61859533e-02,  3.40291671e-02,  1.94095582e-01,  2.04953402e-01,
#          1.39223471e-01,  3.02962303e-01,  5.26758023e-02,  1.41105175e-01,
#         -2.85551548e-02,  6.13124110e-02, -4.68721390e-02,  4.04525585e-02,
#          2.96469271e-01,  1.70450687e-01,  2.02706769e-01,  1.12442918e-01,
#          4.51532036e-01,  7.62367249e-01,  6.54321373e-01,  3.35732341e-01,
#          3.31841141e-01,  9.40914035e-01,  4.69031841e-01,  5.16801596e-01,
#          4.75335956e-01,  4.02946472e-02,  3.43015790e-01,  5.86115360e-01,
#          8.60365748e-01,  5.02330303e-01,  3.75759602e-01,  5.19896805e-01,
#          5.17549038e-01,  5.20608783e-01,  5.33713698e-01,  2.14574829e-01,
#          5.35840809e-01,  7.27517486e-01,  1.82940960e-01,  6.75695777e-01,
#          5.10523140e-01,  5.22918403e-01,  5.35379469e-01,  4.37988043e-02,
#          5.71161151e-01,  4.89119530e-01,  2.98313797e-02,  3.26548278e-01,
#          1.52991563e-02,  3.11736822e-01,  8.48295510e-01,  7.76921436e-02,
#          4.02968854e-01,  7.27646947e-01,  3.64318788e-02,  3.25416982e-01,
#          7.78175741e-02, -4.62139165e-03,  5.83858192e-01,  2.60601044e-01,
#          5.15547693e-01,  2.00559229e-01,  5.12351632e-01,  4.33220059e-01,
#          5.43432415e-01,  7.38341749e-01,  1.74927041e-01,  5.41451991e-01,
#         -1.86692514e-02,  4.44624305e-01,  2.69825637e-01,  4.40542459e-01,
#          5.89845419e-01,  1.13012396e-01,  2.84196883e-01,  4.70657647e-01,
#          6.28281355e-01,  3.15611392e-01,  5.75321436e-01,  5.88860095e-01,
#          2.78108656e-01,  4.17243600e-01,  2.13359877e-01,  2.68454969e-01,
#          7.14838028e-01,  6.51639104e-01,  5.84137082e-01,  5.71205437e-01,
#          1.89004257e-01,  4.38010514e-01,  7.07479417e-01,  3.61223042e-01,
#          1.51243776e-01,  5.17563164e-01,  3.71018410e-01,  4.14934099e-01,
#          5.99595308e-01,  3.61045986e-01,  6.59329951e-01,  3.41981947e-01,
#          4.35317636e-01,  3.01763296e-01,  9.03314531e-01,  6.09816194e-01,
#          6.50409162e-01,  7.20481396e-01,  4.18311656e-01,  4.99779969e-01,
#          1.55285627e-01,  5.32423258e-01,  1.52954787e-01,  5.46447873e-01,
#          8.13869596e-01,  6.79330587e-01,  8.09646845e-01,  4.98022318e-01,
#          7.66530633e-02,  4.54385504e-02,  7.45604411e-02, -6.55990094e-04,
#          5.22800088e-02,  2.86933959e-01,  1.27330542e-01,  5.23968339e-02,
#          1.14109412e-01, -4.00885791e-02,  3.00371144e-02,  1.34193614e-01,
#          2.16618642e-01,  6.90388158e-02, -1.72677077e-02,  9.44562331e-02,
#          7.17125461e-02,  2.55372506e-02,  9.91741940e-02,  5.74107375e-03,
#          1.54880255e-01,  1.89511925e-01, -1.45771010e-02,  3.76941673e-02,
#          1.99497119e-01,  1.74652636e-01,  6.26085401e-02, -3.69605906e-02,
#          8.26684944e-03,  1.06628545e-01, -4.24889252e-02,  3.03100944e-02,
#         -4.14534956e-02,  8.81872047e-03,  2.40640432e-01, -3.52260284e-02,
#          2.73517370e-02,  2.98556149e-01, -3.76949310e-02,  1.81100760e-02,
#         -8.17506313e-02, -6.20612428e-02,  2.11194620e-01,  3.93108139e-03,
#          1.15236402e-01, -1.74662843e-02,  9.56137944e-03,  3.07223331e-02,
#          7.24043275e-05,  1.61562994e-01, -1.60300191e-02,  1.14947349e-01,
#         -9.14049223e-02,  8.72669965e-02, -5.02870530e-02,  4.12375145e-02,
#          1.58664271e-01, -1.59891155e-02,  2.71112621e-02,  1.03629909e-01,
#          1.34188130e-01,  2.02251170e-02,  1.57823637e-01,  7.82281160e-02,
#         -8.13084748e-03,  7.02313185e-02,  2.39290856e-02,  1.63514819e-02,
#          1.91221714e-01,  1.75525486e-01,  9.01323184e-02,  7.54412785e-02,
#         -3.27374265e-02,  1.17890229e-02,  2.83582330e-01,  1.92946494e-02,
#         -3.72434743e-02,  1.79258585e-02, -1.36158764e-02,  1.93896797e-02,
#          1.43730223e-01,  8.07116460e-03,  1.09779991e-01,  2.71290913e-03,
#          4.22509424e-02,  4.29409966e-02,  2.20578015e-01,  1.71491802e-01,
#          1.12348385e-01,  2.86212534e-01,  6.02255948e-02,  1.41265705e-01,
#         -3.85150500e-02,  5.04066423e-02, -5.09741381e-02,  4.36238647e-02,
#          2.46017829e-01,  2.20133781e-01,  1.50357053e-01,  9.19525549e-02],
#        dtype=float32),
#  0.16124889254570007,
#  False)

# %%
train_session.plot_density()
# Out:
# /home/benoit/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/hist.py:119: RuntimeWarning: All-NaN slice encountered
#   sample_range = np.nanmax(y) - np.nanmin(y)
# /home/benoit/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/hist.py:121: RuntimeWarning: All-NaN slice encountered
#   np.nanmin(y) - 0.5 * sample_range,
# /home/benoit/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/hist.py:122: RuntimeWarning: All-NaN slice encountered
#   np.nanmax(y) + 0.5 * sample_range,
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-613b3a074a0b> in <module>
# ----> 1 train_session.plot_density()
#
# ~/Documents/work/RL_DNA/train_session.py in plot_density(self)
#     125         test_set = pd.read_csv("test_set.csv", index_col=0)
#     126         test_set_scores = test_set.loc[:, self.env.reward_func_goal].rename('Test set score')
# --> 127         pd.concat([scores, test_set_scores], axis=1).plot.kde(bw_method=.1)
#     128
#     129     def train(self, n_episode=500, t_max_per_episode=200, graphical=False, agent_subset=None):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in kde(self, bw_method, ind, **kwargs)
#    1286             >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1287         """
# -> 1288         return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#    1289
#    1290     density = kde
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     261         self._compute_plot_data()
#     262         self._setup_subplots()
# --> 263         self._make_plot()
#     264         self._add_table()
#     265         self._make_legend()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/hist.py in _make_plot(self)
#      78
#      79             kwds = self._make_plot_keywords(kwds, y)
# ---> 80             artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#      81             self._add_legend_handle(artists[0], label, index=i)
#      82
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/hist.py in _plot(cls, ax, y, style, bw_method, ind, column_num, stacking_id, **kwds)
#     149
#     150         y = remove_na_arraylike(y)
# --> 151         gkde = gaussian_kde(y, bw_method=bw_method)
#     152
#     153         y = gkde.evaluate(ind)
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/stats/kde.py in __init__(self, dataset, bw_method, weights)
#     194         self.dataset = atleast_2d(asarray(dataset))
#     195         if not self.dataset.size > 1:
# --> 196             raise ValueError("`dataset` input should have multiple elements.")
#     197
#     198         self.d, self.n = self.dataset.shape
#
# ValueError: `dataset` input should have multiple elements.

# %%
train_session.save_model(suffix='0710-raw')

# %%
a = np.array(train_session.rewards_per_episode["a2c_agent"])[1:]

# %%
a[a <= 0]
# Out:
# array([-169.85291323,  -29.93677123,   -9.94647928,  -29.95776756,
#          -9.89340588,   -9.87795719,   -9.94244637,  -19.88838159,
#          -9.78376144,   -9.94982777,  -69.93105348,   -9.92366278,
#          -9.95317671,   -9.88481782,   -9.78837796,   -9.93631242,
#          -9.97285929,   -9.89520814,   -9.84451327,   -9.93995072,
#         -19.92200837,   -9.77168891,   -9.86824988,   -9.79042137,
#          -9.7880377 ,  -19.92578671,  -19.89814471,   -9.94313581,
#          -9.86924613,   -9.94185011,   -9.77627863,  -19.81795828,
#         -19.96410682,   -9.93081892,   -9.89157464,   -9.85105807,
#          -9.8956165 ,   -9.89934511,  -19.92032801,   -9.91549184,
#         -19.908712  ,  -29.94066104,  -19.89826294,   -9.9509282 ,
#         -79.9282086 ,  -29.93356854,   -9.92194422,   -9.82230216,
#          -9.85910945,  -29.93324846,   -9.87466204,   -9.92347696,
#          -9.88264262,  -19.89463998,   -9.94023002,   -9.97023582,
#          -9.94733138,   -9.92451993,   -9.92266302, -159.90508764,
#          -9.91012935,  -39.91377354,   -9.89221031,   -9.9343631 ,
#          -9.90994867,   -9.94729945,   -9.90555874,   -9.94162977,
#          -9.93328948,  -19.94071278,   -9.94665508,   -9.86837088,
#         -29.87843291,   -9.93406583,   -9.94354412,   -9.95581078,
#         -59.88259938,   -9.9530404 ,   -9.91433025,  -29.90335331,
#          -9.92329374,   -9.91503412,   -9.92723445,   -9.8924596 ,
#          -9.95361213,   -9.80336963,  -29.96981553,  -19.94106361,
#          -9.95811098,   -9.88599098,   -9.93436746,   -9.88155292,
#          -9.87290534,  -29.87823186,   -9.93506243,  -19.82230033,
#          -9.89251015,   -9.95874171,   -9.91879461,   -9.96497732,
#         -19.8601447 ,   -9.77540459,   -9.78896938,   -9.93685307,
#         -19.92686468,   -9.84317347,   -9.8083871 ,   -9.94688436,
#         -19.91073902,  -79.93400367,  -19.92225163,   -9.9269416 ,
#          -9.93328183,   -9.94003532,   -9.94158195,   -9.93285966,
#          -9.86410497,   -9.89739416,  -39.94650154,  -39.9643499 ,
#          -9.92641603,  -19.96029757,   -9.94829343,   -9.91296891,
#          -9.93093951,   -9.83247769,   -9.94261622,   -9.95080344,
#         -29.92372473,   -9.95344139,  -19.94002919,   -9.89200153,
#         -19.89500672,   -9.89690924,   -9.9608714 ,   -9.93555757,
#          -9.9165795 ,   -9.94579845,   -9.86640783,   -9.95519581,
#          -9.9101485 ,   -9.81006715,  -29.91870175,   -9.95884587,
#         -29.83212453,   -9.93690481,   -9.88338754,   -9.93264998,
#          -9.94977729,   -9.95844141,  -29.92775213,   -9.7965408 ,
#          -9.91565247,   -9.91380849,   -9.92947995,   -9.89599577,
#          -9.84602736,   -9.95967064,  -19.92714746,   -9.92847669,
#          -9.82030126,  -19.94022928,  -59.94986895,   -9.90662336,
#          -9.91085716,  -19.8042959 ,   -9.95256979,   -9.94771355,
#          -9.94295529,   -9.9108804 ,   -9.8562911 ,   -9.83575523,
#          -9.90693181,   -9.85729723,   -9.95580205,   -9.90453736,
#          -9.93730841,   -9.84650823,   -9.86463083,  -19.90896885,
#          -9.90607375,   -9.90694267,   -9.94348478,   -9.95884785,
#         -19.95169475,   -9.96527091,   -9.90422708,  -19.92195353,
#         -19.91982777,   -9.93717369,   -9.89471937,   -9.95155647,
#          -9.79006866,  -19.94057919,   -9.90906916,   -9.84457974,
#          -9.92848443,   -9.95269826,   -9.89692382,   -9.84225665,
#         -19.84642538,   -9.59113961])

# %%
b = np.array(train_session.reward_per_time_step["a2c_agent"])[1:]

# %%
b[b >= 0].shape[0] - b[b <= 0].shape[0]
# Out:
# 886

# %%
train_session.reward_per_time_step["a2c_agent"][train_session.reward_per_time_step["a2c_agent"] > .60]
# Out:
# array([0.6667548 , 0.60170127, 0.65782997, 0.63893074, 0.66179251,
#        0.64561439, 0.70317611, 0.71903552, 0.68008956, 0.60722298,
#        0.6909626 , 0.75096821, 0.62512117, 0.72650619, 0.606064  ,
#        0.63476332, 0.77182073, 0.63462014, 0.6488169 , 0.61257225,
#        0.6657833 , 0.62061772, 0.60348487, 0.64077849, 0.68226678,
#        0.70294759, 0.64984097, 0.7633385 , 0.64267869, 0.6790415 ,
#        0.60613658, 0.66673484, 0.65242333, 0.85447252, 0.69232798,
#        0.67011794, 0.64340799, 0.67846479, 0.73180237, 0.61950533,
#        0.68784258, 0.68916307, 0.68294038, 0.62396943, 0.73442558,
#        0.71184662, 0.75954778, 0.67736588, 0.6027206 , 0.77295759,
#        0.75905788, 0.78492733, 0.76038253, 0.67871556, 0.62265427,
#        0.64268848, 0.75894994, 0.61272737, 0.78926467, 0.64902449,
#        0.682592  , 0.75606137, 0.63285924, 0.60175642, 0.67535348,
#        0.64948897, 0.61287603, 0.661961  , 0.68116212, 0.63662113,
#        0.62037278, 0.68894646, 0.64492404, 0.60454041, 0.64057743,
#        0.67737044, 0.63991278, 0.65653923, 0.61705412, 0.6115842 ,
#        0.73645187, 0.64717789, 0.66384027, 0.69596564, 0.70344242,
#        0.65208596, 0.75929669, 0.61960991, 0.73658487, 0.66271039,
#        0.69043652, 0.66177268, 0.64790685, 0.60994297, 0.61167751,
#        0.65641846, 0.63670992, 0.73471364, 0.64849816, 0.62753027,
#        0.63963174, 0.65392086, 0.70492262, 0.61713498, 0.62843606,
#        0.61090176, 0.76342182, 0.65100072, 0.60547866, 0.68233396,
#        0.64454167, 0.60116921, 0.60428137, 0.60074419, 0.64397503,
#        0.63698262, 0.69356619, 0.62449306, 0.6235883 , 0.64129801,
#        0.71780365, 0.71419173, 0.63782217, 0.63541456, 0.64018755,
#        0.62968355, 0.60538139, 0.6438126 , 0.6462004 , 0.72974724,
#        0.65945369, 0.72839941, 0.68428623, 0.72953391, 0.68944182,
#        0.66203089, 0.62027029, 0.63898746, 0.64910001, 0.74917122,
#        0.76098041, 0.67564101, 0.68098623, 0.67009854, 0.61256793,
#        0.62613232, 0.71803143, 0.76468173, 0.60908077, 0.63837315,
#        0.66855847, 0.63588788, 0.61043661, 0.66535032, 0.72443287,
#        0.64845641, 0.64925314, 0.67030718, 0.80968512, 0.6288396 ,
#        0.69441448, 0.72040456, 0.64085747, 0.60922793, 0.67966373,
#        0.75234119, 0.63919394, 0.62098788, 0.65783426, 0.61344232,
#        0.68718784, 0.81682371, 0.72844396, 0.76356136, 0.71589522,
#        0.65897012, 0.65522325, 0.65540138, 0.79417328, 0.75346236,
#        0.61453312, 0.6122936 , 0.7027066 , 0.61815167, 0.62174217,
#        0.61060527, 0.61643337, 0.76080794, 0.78971346, 0.6795923 ,
#        0.64502709, 0.62351227, 0.65784039, 0.63004793, 0.61377907,
#        0.65007579, 0.76354165, 0.61334939, 0.81432939, 0.67268508,
#        0.63832268, 0.71771127, 0.63574445, 0.76133521, 0.7601565 ,
#        0.61781923, 0.69458824, 0.64105933, 0.6795955 , 0.6811135 ,
#        0.60961814, 0.72661023, 0.64414942, 0.65696579, 0.66297366,
#        0.71060518, 0.70318189, 0.62350096, 0.64510991, 0.63590024,
#        0.74757163, 0.62692491, 0.67484042, 0.71268106, 0.82772115,
#        0.61871617, 0.60927305, 0.66267277, 0.62645743, 0.62004827,
#        0.6758863 , 0.6742947 , 0.66515933, 0.60207662, 0.77561703,
#        0.69221604, 0.60748513, 0.65579509, 0.62488132, 0.62287159,
#        0.64197007, 0.64935865, 0.65903407, 0.60641897, 0.7113519 ,
#        0.67649573, 0.62326439, 0.60591288, 0.84122891, 0.6331463 ,
#        0.63171005])

# %%
np.ma.apply_along_axis(np.ma.masked_not_equal(train_session.reward_per_time_step["a2c_agent"], -1.0))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-6c8b01a21e81> in <module>
# ----> 1 np.ma.apply_along_axis(np.ma.masked_not_equal(train_session.reward_per_time_step["a2c_agent"], -1.0))
#
# TypeError: apply_along_axis() missing 2 required positional arguments: 'axis' and 'arr'

# %%
import numpy as np
train_session.reward_per_time_step["a2c_agent"] = np.ma.masked_not_equal(train_session.reward_per_time_step["a2c_agent"], -1.0)
series_mvg = utils.rolling_window(train_session.reward_per_time_step["a2c_agent"], window=10)
series_mvg_avg = np.mean(series_mvg, axis=1)
plt.plot(range(len(series_mvg_avg)), series_mvg_avg)

# %%
train_session.agents["a2c_agent"].critic(torch.rand(1, 400).cuda())
# Out:
# tensor([[-0.0450]], device='cuda:0', grad_fn=<AddmmBackward>)

# %%
state = env.reset()

# %%
(1, ) + state.shape
# Out:
# (1, 400)

# %%
a = torch.tensor([11, 23,  3], device=v.device)

# %%
a.cpu().numpy()
# Out:
# array([11, 23,  3])

# %%
a.prod()
# Out:
# tensor(759, device='cuda:0')

# %%
import utils

# %%
utils.to_tensor([[float(3)]])
# Out:
# tensor([[3.]], device='cuda:0')

# %%
torch.save(train_session.agents["a2c_agent"].critic.state_dict(), "/home/benoit/Documents/work/RL_DNA/saved_model/a2c_agent_critic_1.pth")

# %%
torch.save(train_session.agents["a2c_agent"].actor.state_dict(), "/home/benoit/Documents/work/RL_DNA/saved_model/a2c_agent_actor_1.pth")

# %%
max([.9, .8])
# Out:
# 0.9
